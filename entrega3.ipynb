# %%
import cv2,argparse,glob
import numpy as np

# %%
# mouse callback function
def showPixelValue(event,x,y,flags,param):
    global img, combinedResult, placeholder
    if event == cv2.EVENT_LBUTTONDOWN:
        bgr = img[y,x]
        print("BGR",bgr)
        ycb = cv2.cvtColor(np.uint8([[bgr]]),cv2.COLOR_BGR2YCrCb)[0][0]
        lab = cv2.cvtColor(np.uint8([[bgr]]),cv2.COLOR_BGR2Lab)[0][0]
        hsv = cv2.cvtColor(np.uint8([[bgr]]),cv2.COLOR_BGR2HSV)[0][0]
        print("YCB",ycb)
        print("Lab",lab)
        print("HSV",hsv)
        
    if event == cv2.EVENT_MOUSEMOVE:
        # get the value of pixel from the location of mouse in (x,y)
        bgr = img[y,x]
     

        # Convert the BGR pixel into other colro formats
        ycb = cv2.cvtColor(np.uint8([[bgr]]),cv2.COLOR_BGR2YCrCb)[0][0]
        lab = cv2.cvtColor(np.uint8([[bgr]]),cv2.COLOR_BGR2Lab)[0][0]
        hsv = cv2.cvtColor(np.uint8([[bgr]]),cv2.COLOR_BGR2HSV)[0][0]
        
        # Create an empty placeholder for displaying the values
        placeholder = np.zeros((img.shape[0],400,3),dtype=np.uint8)

        # fill the placeholder with the values of color spaces
        cv2.putText(placeholder, "BGR {}".format(bgr), (20, 70), cv2.FONT_HERSHEY_COMPLEX, .9, (255,255,255), 1, cv2.LINE_AA)
        cv2.putText(placeholder, "HSV {}".format(hsv), (20, 140), cv2.FONT_HERSHEY_COMPLEX, .9, (255,255,255), 1, cv2.LINE_AA)
        cv2.putText(placeholder, "YCrCb {}".format(ycb), (20, 210), cv2.FONT_HERSHEY_COMPLEX, .9, (255,255,255), 1, cv2.LINE_AA)
        cv2.putText(placeholder, "LAB {}".format(lab), (20, 280), cv2.FONT_HERSHEY_COMPLEX, .9, (255,255,255), 1, cv2.LINE_AA)
        
        # Combine the two results to show side by side in a single image
        combinedResult = np.hstack([img,placeholder])
        
        cv2.imshow('Pressione  A para Anterior, P para proxima imagem',combinedResult)


if __name__ == '__main__' :
     
    # load the image and setup the mouse callback function
    global img
    files = glob.glob('images/rub*.jpg')
    files.sort()
    img = cv2.imread(files[0])
    img = cv2.resize(img,(400,400))
    cv2.imshow('Pressione  A para Anterior, P para proxima imagem',img)

    # Create an empty window
    cv2.namedWindow('Pressione  A para Anterior, P para proxima imagem')
    # Create a callback function for any event on the mouse
    cv2.setMouseCallback('Pressione  A para Anterior, P para proxima imagem',showPixelValue)
    i = 0
    while(1):
        k = cv2.waitKey(1) & 0xFF
        # check next image in the folder
        if k == ord('p'):
            i += 1
            img = cv2.imread(files[i%len(files)])
            img = cv2.resize(img,(400,400))
            cv2.imshow('Pressione  A para Anterior, P para proxima imagem',img)
 
        # check previous image in folder
        elif k == ord('n'):
            i -= 1
            img = cv2.imread(files[i%len(files)])
            img = cv2.resize(img,(400,400))
            cv2.imshow('Pressione  A para Anterior, P para proxima imagem',img)

        elif k == 27:
            cv2.destroyAllWindows()
            break
# Out:
# BGR [108  54  13]
# YCB [ 48 103 162]
# Lab [ 58 137  93]
# HSV [107 224 108]
# BGR [108  57  17]
# YCB [ 51 104 160]
# Lab [ 61 135  94]
# HSV [107 215 108]
# BGR [110  57  16]
# YCB [ 51 103 161]
# Lab [ 62 135  93]
# HSV [107 218 110]
# BGR [110  54  13]
# YCB [ 48 103 163]
# Lab [ 59 138  91]
# HSV [107 225 110]
# BGR [109  53  12]
# YCB [ 47 103 163]
# Lab [ 58 138  92]
# HSV [107 227 109]
# BGR [75 50 31]
# YCB [ 47 117 144]
# Lab [ 52 129 110]
# HSV [107 150  75]
# BGR [91 61 36]
# YCB [ 57 113 147]
# Lab [ 64 129 107]
# HSV [106 154  91]
# BGR [93 67 46]
# YCB [ 64 115 144]
# Lab [ 71 128 110]
# HSV [107 129  93]
# BGR [101  77  53]
# YCB [ 73 114 144]
# Lab [ 81 126 111]
# HSV [105 121 101]
# BGR [93 63 38]
# YCB [ 59 113 147]
# Lab [ 66 129 107]
# HSV [106 151  93]
# BGR [88 58 29]
# YCB [ 53 111 148]
# Lab [ 60 128 107]
# HSV [105 171  88]
# BGR [79 47 21]
# YCB [ 43 112 148]
# Lab [ 48 131 105]
# HSV [107 187  79]
# BGR [99 72 45]
# YCB [ 67 112 146]
# Lab [ 76 127 109]
# ...

# %% [markdown]
# # Exercicio 1

# %% [markdown]
# ## Analizando primeiramente BGR

# %%
# #Criando vetor BGR
# #QUADRADO VERDE
# BGR = [[23,100,16],
# [26,98,15],
# [26,104,21],
# [28,106,23],
# [23,101,17],
# [23,71,22],
# [19,70,20],
# [19,68,18],
# [19,67,19],
# [20,69,19],
# [19,71,18],
# [18,70,17],
# [19,71,18],
# [19,71,18],
# [19,70,20],
# [21,89,30],
# [20,88,29],
# [17,90,28],
# [17,90,28],
# [18,89,35],
# [38,126,20],
# [45,127,20],
# [39,124,19],
# [39,128,19],
# [41,126,22],
# [18,135,18],
# [16,132,19],
# [16,135,16],
# [17,136,14],
# [19,135,22],
# [42,129,30],
# [42,134,29],
# [41,131,27],
# [40,133,28],
# [47,136,40],
# [40,151,5],
# [45,154,7],
# [43,154,2],
# [42,152,10],
# [42,154,2],
# [40,157,17],
# [39,156,17],
# [43,158,19],
# [46,160,29],
# [40,156,19],
# [21,81,20],
# [22,82,21],
# [19,84,19],
# [20,82,20],
# [20,80,20]]

#QUADRADO AZUL
BGR = [[108,54,13],
[108,57,17],
[110,57,16],
[110,54,13],
[109,53,12],
[75,50,31],
[91,61,36],
[93,67,46],
[101,77,53],
[93,63,38],
[88,58,29],
[79,47,21],
[99,72,45],
[83,55,31],
[88,58,29],
[119,80,52],
[113,65,35],
[116,70,39],
[125,84,57],
[123,76,44],
[149,91,26],
[148,94,33],
[141,87,24],
[150,89,25],
[144,82,18],
[137,102,39],
[144,102,31],
[137,95,20],
[139,97,22],
[132,91,16],
[164,101,41],
[175,100,32],
[173,96,27],
[168,95,27],
[173,95,26],
[193,102,14],
[195,111,16],
[192,99,,6],
[193,99,,4],
[196,103,,8],
[169,113,42],
[176,118,42],
[173,110,30],
[176,107,20],
[174,105,18],
[92,52,23],
[93,54,22],
[91,52,20],
[88,48,20],
[93,52,20],
[109,58,18],
[110,56,15],
[107,53,12],
[107,53,12],
[110,54,13],]

# %%
#Armazenando B no vetor
B = []
for cor in BGR:
    B.append(cor[0])
    #Armazenando G no vetor

G = []
for cor in BGR:
    G.append(cor[1])

#Armazenando R no vetor
R = []
for cor in BGR:
    R.append(cor[2])

# %% [markdown]
# ## Média total de BGR

# %%
#Media geral do B G e R
print("Media total dos pixels B "+str(np.mean(B)))
print("Media total dos pixels G "+str(np.mean(G)))
print("Media total dos pixels R "+str(np.mean(R)))

# %% [markdown]
# ## Média por imagem B

# %%
#Media por imagem B
imgB1 = B[0:5]
imgB2 = B[5:10]
imgB3 = B[10:15]
imgB4 = B[15:20]
imgB5 = B[20:25]
imgB6 = B[25:30]
imgB7 = B[30:35]
imgB8 = B[35:40]
imgB9 = B[40:45]
imgB10 = B[45:50]
print("Media dos pixels B da imagem 1 = "+str(np.mean(imgB1)))
print("Media dos pixels B da imagem 2 = "+str(np.mean(imgB2)))
print("Media dos pixels B da imagem 3 = "+str(np.mean(imgB3)))
print("Media dos pixels B da imagem 4 = "+str(np.mean(imgB4)))
print("Media dos pixels B da imagem 5 = "+str(np.mean(imgB5)))
print("Media dos pixels B da imagem 6 = "+str(np.mean(imgB6)))
print("Media dos pixels B da imagem 7 = "+str(np.mean(imgB7)))
print("Media dos pixels B da imagem 8 = "+str(np.mean(imgB8)))
print("Media dos pixels B da imagem 9 = "+str(np.mean(imgB9)))
print("Media dos pixels B da imagem 10 = "+str(np.mean(imgB10)))

# %% [markdown]
# ## Média por imagem G

# %%
#Media por imagem G
imgG1 = G[0:5]
imgG2 = G[5:10]
imgG3 = G[10:15]
imgG4 = G[15:20]
imgG5 = G[20:25]
imgG6 = G[25:30]
imgG7 = G[30:35]
imgG8 = G[35:40]
imgG9 = G[40:45]
imgG10 = G[45:50]
print("Media dos pixels G da imagem 1 = "+str(np.mean(imgG1)))
print("Media dos pixels G da imagem 2 = "+str(np.mean(imgG2)))
print("Media dos pixels G da imagem 3 = "+str(np.mean(imgG3)))
print("Media dos pixels G da imagem 4 = "+str(np.mean(imgG4)))
print("Media dos pixels G da imagem 5 = "+str(np.mean(imgG5)))
print("Media dos pixels G da imagem 6 = "+str(np.mean(imgG6)))
print("Media dos pixels G da imagem 7 = "+str(np.mean(imgG7)))
print("Media dos pixels G da imagem 8 = "+str(np.mean(imgG8)))
print("Media dos pixels G da imagem 9 = "+str(np.mean(imgG9)))
print("Media dos pixels G da imagem 10 = "+str(np.mean(imgG10)))

# %% [markdown]
# ## Média por imagem R

# %%
#Media por imagem R
imgR1 = R[0:5]
imgR2 = R[5:10]
imgR3 = R[10:15]
imgR4 = R[15:20]
imgR5 = R[20:25]
imgR6 = R[25:30]
imgR7 = R[30:35]
imgR8 = R[35:40]
imgR9 = R[40:45]
imgR10 = R[45:50]
print("Media dos pixels R da imagem 1 = "+str(np.mean(imgR1)))
print("Media dos pixels R da imagem 2 = "+str(np.mean(imgR2)))
print("Media dos pixels R da imagem 3 = "+str(np.mean(imgR3)))
print("Media dos pixels R da imagem 4 = "+str(np.mean(imgR4)))
print("Media dos pixels R da imagem 5 = "+str(np.mean(imgR5)))
print("Media dos pixels R da imagem 6 = "+str(np.mean(imgR6)))
print("Media dos pixels R da imagem 7 = "+str(np.mean(imgR7)))
print("Media dos pixels R da imagem 8 = "+str(np.mean(imgR8)))
print("Media dos pixels R da imagem 9 = "+str(np.mean(imgR9)))
print("Media dos pixels R da imagem 10 = "+str(np.mean(imgR10)))

# %% [markdown]
# ## Desvio padrão geral BGR

# %%
#Desvio padrão do B G e R
print("Desvio padrao total dos pixels B "+str(np.std(B)))
print("Desvio padrao total dos pixels G "+str(np.std(G)))
print("Desvio padrao total dos pixels R "+str(np.std(R)))

# %% [markdown]
# ## Desvio padrão por imagem B

# %%
#Desvio padrao por imagem B
print("Desvio padrao dos pixels B da imagem 1 = "+str(np.std(imgB1)))
print("Desvio padrao dos pixels B da imagem 2 = "+str(np.std(imgB2)))
print("Desvio padrao dos pixels B da imagem 3 = "+str(np.std(imgB3)))
print("Desvio padrao dos pixels B da imagem 4 = "+str(np.std(imgB4)))
print("Desvio padrao dos pixels B da imagem 5 = "+str(np.std(imgB5)))
print("Desvio padrao dos pixels B da imagem 6 = "+str(np.std(imgB6)))
print("Desvio padrao dos pixels B da imagem 7 = "+str(np.std(imgB7)))
print("Desvio padrao dos pixels B da imagem 8 = "+str(np.std(imgB8)))
print("Desvio padrao dos pixels B da imagem 9 = "+str(np.std(imgB9)))
print("Desvio padrao dos pixels B da imagem 10 = "+str(np.std(imgB10)))

# %% [markdown]
# ## Desvio padrão por imagem G

# %%
#Desvio padrao por imagem G
print("Desvio padrao dos pixels G da imagem 1 = "+str(np.std(imgG1)))
print("Desvio padrao dos pixels G da imagem 2 = "+str(np.std(imgG2)))
print("Desvio padrao dos pixels G da imagem 3 = "+str(np.std(imgG3)))
print("Desvio padrao dos pixels G da imagem 4 = "+str(np.std(imgG4)))
print("Desvio padrao dos pixels G da imagem 5 = "+str(np.std(imgG5)))
print("Desvio padrao dos pixels G da imagem 6 = "+str(np.std(imgG6)))
print("Desvio padrao dos pixels G da imagem 7 = "+str(np.std(imgG7)))
print("Desvio padrao dos pixels G da imagem 8 = "+str(np.std(imgG8)))
print("Desvio padrao dos pixels G da imagem 9 = "+str(np.std(imgG9)))
print("Desvio padrao dos pixels G da imagem 10 = "+str(np.std(imgG10)))

# %% [markdown]
# ## Desvio padrão por imagem R

# %%
#Desvio padrão por imagem R
print("Desvio padrao dos pixels R da imagem 1 = "+str(np.std(imgR1)))
print("Desvio padrao dos pixels R da imagem 2 = "+str(np.std(imgR2)))
print("Desvio padrao dos pixels R da imagem 3 = "+str(np.std(imgR3)))
print("Desvio padrao dos pixels R da imagem 4 = "+str(np.std(imgR4)))
print("Desvio padrao dos pixels R da imagem 5 = "+str(np.std(imgR5)))
print("Desvio padrao dos pixels R da imagem 6 = "+str(np.std(imgR6)))
print("Desvio padrao dos pixels R da imagem 7 = "+str(np.std(imgR7)))
print("Desvio padrao dos pixels R da imagem 8 = "+str(np.std(imgR8)))
print("Desvio padrao dos pixels R da imagem 9 = "+str(np.std(imgR9)))
print("Desvio padrao dos pixels R da imagem 10 = "+str(np.std(imgR10)))

# %% [markdown]
# ## Analizando primeiramente Lab

# %%
# #Criando vetor BGR
# # Quadrado verde
# LAR = [
# [93,88,163],
# [91,89,161],
# [97,88,163],
# [99,88,163],
# [94,88,163],
# [66,100,152],
# [65,100,153],
# [63,100,153],
# [62,100,152],
# [64,100,152],
# [66,98,153],
# [65,98,154],
# [66,98,153],
# [66,98,153],
# [65,100,153],
# [84,95,160],
# [83,94,161],
# [85,94,162],
# [85,94,162],
# [84,96,162],
# [117,81,166],
# [118,81,164],
# [115,82,165],
# [119,81,167],
# [117,82,165],
# [125,76,176],
# [122,77,176],
# [125,76,177],
# [126,76,177],
# [125,77,176],
# [120,82,166],
# [125,80,168],
# [122,81,167],
# [124,80,168],
# [127,82,167],
# [139,72,174],
# [141,72,174],
# [141,71,174],
# [140,72,174],
# [141,71,175],
# [144,71,177],
# [143,71,177],
# [145,71,176],
# [147,72,175],
# [143,71,176],
# [76,95,157],
# [77,95,157],
# [78,94,159],
# [77,95,158],
# [75,95,157]]

#Quadrado azul
LAR = [[58,137,93],
[61,135,94],
[62,135,93],
[59,138,91],
[58,138,92],
[52,129,110],
[64,129,107],
[71,128,110],
[81,126,111],
[66,129,107],
[60,128,107],
[48,131,105],
[76,127,109],
[57,129,108],
[60,128,107],
[86,130,103],
[71,134,97],
[76,132,98],
[90,131,102],
[82,132,98],
[96,130,90],
[99,128,93],
[91,129,93],
[95,131,89],
[88,133,88],
[104,120,103],
[104,121,99],
[97,122,98],
[99,122,99],
[93,122,99],
[107,131,89],
[107,135,82],
[104,136,81],
[102,135,83],
[103,137,81],
[111,140,74],
[118,135,77],
[108,141,73],
[108,141,72],
[112,139,73],
[117,126,92],
[122,125,91],
[114,128,88],
[112,130,85],
[110,130,85],
[55,133,101],
[57,132,101],
[54,132,101],
[51,133,101],
[55,133,100],
[63,134,94],
[61,136,93],
[58,136,93],
[58,136,93],
[59,138,91]]

# %%
#Armazenando B no vetor
L = []
for cor in LAR:
    L.append(cor[0])
    
#Armazenando A no vetor
A = []
for cor in LAR:
    A.append(cor[1])

#Armazenando R no vetor
RL = []
for cor in LAR:
    RL.append(cor[2])

# %% [markdown]
# ## Média total de Lab

# %%
#Media geral do B G e R
print("Media total dos pixels L "+str(np.mean(L)))
print("Media total dos pixels A "+str(np.mean(A)))
print("Media total dos pixels R "+str(np.mean(RL)))

# %% [markdown]
# ## Média por imagem L

# %%
#Media por imagem L
imgL1 = L[0:5]
imgL2 = L[5:10]
imgL3 = L[10:15]
imgL4 = L[15:20]
imgL5 = L[20:25]
imgL6 = L[25:30]
imgL7 = L[30:35]
imgL8 = L[35:40]
imgL9 = L[40:45]
imgL10 = L[45:50]
print("Media dos pixels L da imagem 1 = "+str(np.mean(imgL1)))
print("Media dos pixels L da imagem 2 = "+str(np.mean(imgL2)))
print("Media dos pixels L da imagem 3 = "+str(np.mean(imgL3)))
print("Media dos pixels L da imagem 4 = "+str(np.mean(imgL4)))
print("Media dos pixels L da imagem 5 = "+str(np.mean(imgL5)))
print("Media dos pixels L da imagem 6 = "+str(np.mean(imgL6)))
print("Media dos pixels L da imagem 7 = "+str(np.mean(imgL7)))
print("Media dos pixels L da imagem 8 = "+str(np.mean(imgL8)))
print("Media dos pixels L da imagem 9 = "+str(np.mean(imgL9)))
print("Media dos pixels L da imagem 10 = "+str(np.mean(imgL10)))

# %% [markdown]
# ## Média por imagem A

# %%
#Media por imagem A
imgA1 = A[0:5]
imgA2 = A[5:10]
imgA3 = A[10:15]
imgA4 = A[15:20]
imgA5 = A[20:25]
imgA6 = A[25:30]
imgA7 = A[30:35]
imgA8 = A[35:40]
imgA9 = A[40:45]
imgA10 = A[45:50]
print("Media dos pixels A da imagem 1 = "+str(np.mean(imgA1)))
print("Media dos pixels A da imagem 2 = "+str(np.mean(imgA2)))
print("Media dos pixels A da imagem 3 = "+str(np.mean(imgA3)))
print("Media dos pixels A da imagem 4 = "+str(np.mean(imgA4)))
print("Media dos pixels A da imagem 5 = "+str(np.mean(imgA5)))
print("Media dos pixels A da imagem 6 = "+str(np.mean(imgA6)))
print("Media dos pixels A da imagem 7 = "+str(np.mean(imgA7)))
print("Media dos pixels A da imagem 8 = "+str(np.mean(imgA8)))
print("Media dos pixels A da imagem 9 = "+str(np.mean(imgA9)))
print("Media dos pixels A da imagem 10 = "+str(np.mean(imgA10)))

# %% [markdown]
# ## Média por imagem b

# %%
#Media por imagem RL
imgRL1 = RL[0:5]
imgRL2 = RL[5:10]
imgRL3 = RL[10:15]
imgRL4 = RL[15:20]
imgRL5 = RL[20:25]
imgRL6 = RL[25:30]
imgRL7 = RL[30:35]
imgRL8 = RL[35:40]
imgRL9 = RL[40:45]
imgRL10 = RL[45:50]
print("Media dos pixels RL da imagem 1 = "+str(np.mean(imgRL1)))
print("Media dos pixels RL da imagem 2 = "+str(np.mean(imgRL2)))
print("Media dos pixels RL da imagem 3 = "+str(np.mean(imgRL3)))
print("Media dos pixels RL da imagem 4 = "+str(np.mean(imgRL4)))
print("Media dos pixels RL da imagem 5 = "+str(np.mean(imgRL5)))
print("Media dos pixels RL da imagem 6 = "+str(np.mean(imgRL6)))
print("Media dos pixels RL da imagem 7 = "+str(np.mean(imgRL7)))
print("Media dos pixels RL da imagem 8 = "+str(np.mean(imgRL8)))
print("Media dos pixels RL da imagem 9 = "+str(np.mean(imgRL9)))
print("Media dos pixels RL da imagem 10 = "+str(np.mean(imgRL10)))

# %% [markdown]
# ## Desvio padrão geral Lab

# %%
#Desvio padrão do L A e R
print("Desvio padrao total dos pixels L "+str(np.std(L)))
print("Desvio padrao total dos pixels A "+str(np.std(A)))
print("Desvio padrao total dos pixels R "+str(np.std(RL)))

# %% [markdown]
# ## Desvio padrão por imagem L

# %%
#Desvio padrao por imagem L
print("Desvio padrao dos pixels L da imagem 1 = "+str(np.std(imgL1)))
print("Desvio padrao dos pixels L da imagem 2 = "+str(np.std(imgL2)))
print("Desvio padrao dos pixels L da imagem 3 = "+str(np.std(imgL3)))
print("Desvio padrao dos pixels L da imagem 4 = "+str(np.std(imgL4)))
print("Desvio padrao dos pixels L da imagem 5 = "+str(np.std(imgL5)))
print("Desvio padrao dos pixels L da imagem 6 = "+str(np.std(imgL6)))
print("Desvio padrao dos pixels L da imagem 7 = "+str(np.std(imgL7)))
print("Desvio padrao dos pixels L da imagem 8 = "+str(np.std(imgL8)))
print("Desvio padrao dos pixels L da imagem 9 = "+str(np.std(imgL9)))
print("Desvio padrao dos pixels L da imagem 10 = "+str(np.std(imgL10)))

# %% [markdown]
# ## Desvio padrão por imagem A

# %%
#Desvio padrao por imagem A
print("Desvio padrao dos pixels A da imagem 1 = "+str(np.std(imgA1)))
print("Desvio padrao dos pixels A da imagem 2 = "+str(np.std(imgA2)))
print("Desvio padrao dos pixels A da imagem 3 = "+str(np.std(imgA3)))
print("Desvio padrao dos pixels A da imagem 4 = "+str(np.std(imgA4)))
print("Desvio padrao dos pixels A da imagem 5 = "+str(np.std(imgA5)))
print("Desvio padrao dos pixels A da imagem 6 = "+str(np.std(imgA6)))
print("Desvio padrao dos pixels A da imagem 7 = "+str(np.std(imgA7)))
print("Desvio padrao dos pixels A da imagem 8 = "+str(np.std(imgA8)))
print("Desvio padrao dos pixels A da imagem 9 = "+str(np.std(imgA9)))
print("Desvio padrao dos pixels A da imagem 10 = "+str(np.std(imgA10)))

# %% [markdown]
# ## Desvio padrão por imagem b

# %%
#Desvio padrao por imagem RL
print("Desvio padrao dos pixels RL da imagem 1 = "+str(np.std(imgRL1)))
print("Desvio padrao dos pixels RL da imagem 2 = "+str(np.std(imgRL2)))
print("Desvio padrao dos pixels RL da imagem 3 = "+str(np.std(imgRL3)))
print("Desvio padrao dos pixels RL da imagem 4 = "+str(np.std(imgRL4)))
print("Desvio padrao dos pixels RL da imagem 5 = "+str(np.std(imgRL5)))
print("Desvio padrao dos pixels RL da imagem 6 = "+str(np.std(imgRL6)))
print("Desvio padrao dos pixels RL da imagem 7 = "+str(np.std(imgRL7)))
print("Desvio padrao dos pixels RL da imagem 8 = "+str(np.std(imgRL8)))
print("Desvio padrao dos pixels RL da imagem 9 = "+str(np.std(imgRL9)))
print("Desvio padrao dos pixels RL da imagem 10 = "+str(np.std(imgRL10)))

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style='whitegrid')

# %%
dados = pd.DataFrame({'a':[312,12,12]}) # transforma as listas em um dataframe
dados.plot.hist()

# %%
dados = pd.DataFrame({'B':B, 'G':G, 'R':R}) # transforma as listas em um dataframe
dados.plot()
